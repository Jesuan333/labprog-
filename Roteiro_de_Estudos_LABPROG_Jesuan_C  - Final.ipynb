# %% [markdown]
# # Roteiro de estudos de Laboratório de programação

# %% [markdown]
# Jesuan Caielo dos Santos Lopes

# %% [markdown]
# Q1

# %%
n1 = int(input("Digite o 1º número: "))
n2 = int(input("Digite o 2º número: "))
n3 = int(input("Digite o 3º número: "))
n4 = int(input("Digite o 4º número: "))
n5 = int(input("Digite o 5º número: "))
n6 = int(input("Digite o 6º número: "))
n7 = int(input("Digite 0 7º número: "))
n8 = int(input("Digite o 8º número: "))
n9 = int(input("Digite o 9º número: "))
n10 = int(input("Digite o 10º número: "))

soma_positivos = 0

if n1 > 0:
  soma_positivos += n1
if n2 > 0:
  soma_positivos += n2
if n3 > 0:
  soma_positivos += n3
if n4 > 0:
  soma_positivos += n4
if n5 > 0:
  soma_positivos += n5
if n6 > 0:
  soma_positivos += n6
if n7 > 0:
  soma_positivos += n7
if n8 > 0:
  soma_positivos += n8
if n9 > 0:
  soma_positivos += n9
if n10 > 0:
  soma_positivos += n10


media = (n1+n2+n3+n4+n5+n6+n7+n8+n9+n10)/10

print("Soma dos positivos:", soma_positivos)
print("Média:", media)
# Out:
# Soma dos positivos: 55
# Média: 5.5

# %% [markdown]
# Q2

# %%
# Entrada de dados
curso = input("Digite o nome do seu curso: ")
faculdade = input("Digite o nome da sua faculdade: ")

# Saída formatada
print("Eu estudo " + curso + " na " + faculdade)
# Out:
# Eu estudo efghj na xcvgbn

# %% [markdown]
# Q3

# %%
base = float(input("Base: "))
altura = float(input("Altura: "))

perimetro = 2 * (base + altura)

print("Perímetro:", perimetro)
# Out:
# Base: 2
# Altura: 2
# Perímetro: 8.0

# %% [markdown]
# Q4

# %%
reais = float(input("Valor em reais: "))
cotacao = float(input("Cotação do dólar: "))

dolar = reais / cotacao

print("Valor em dólar:", dolar)
# Out:
# Valor em dólar: 0.75

# %% [markdown]
# Q5

# %%
ano_nascimento = int(input("Ano de nascimento: "))
ano_atual = int(input("Ano atual: "))

idade = ano_atual - ano_nascimento

print("Idade:", idade)

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")
# Out:
# Ano de nascimento: 2007
# Ano atual: 2026
# Idade: 19
# Maior de idade

# %% [markdown]
# Q6

# %%
n1 = float(input("Número 1: "))
n2 = float(input("Número 2: "))

print("1 - Soma")
print("2 - Subtração")

op = int(input("Escolha: "))

if op == 1:
    print("Resultado:", n1 + n2)
elif op == 2:
    print("Resultado:", n1 - n2)
else:
    print("Operação inválida")
# Out:
# 1 - Soma
# 2 - Subtração
# Resultado: 6.0

# %% [markdown]
# Q7

# %%
n = int(input("Número: "))

print(n, "x 1 =", n*1)
print(n, "x 2 =", n*2)
print(n, "x 3 =", n*3)
print(n, "x 4 =", n*4)
print(n, "x 5 =", n*5)
print(n, "x 6 =", n*6)
print(n, "x 7 =", n*7)
print(n, "x 8 =", n*8)
print(n, "x 9 =", n*9)
print(n, "x 10 =", n*10)
# Out:
# Número: 10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# Q8

# %%
idade = int(input("Idade: "))
peso = float(input("Peso: "))
cnh = input("Possui CNH? (Sim/Não): ")

print(idade, type(idade))
print(peso, type(peso))
print(cnh, type(cnh))
# Out:
# 18 <class 'int'>
# 101.0 <class 'float'>
# Sim <class 'str'>

# %% [markdown]
# Q9

# %%
rua = input("Rua: ")
numero = int(input("Número: "))
bairro = input("Bairro: ")
cidade = input("Cidade: ")

print("Você mora na Rua", rua, ", nº", numero, ", no bairro", bairro, ", localizado em", cidade)
# Out:
# Você mora na Rua fyguh , nº 999 , no bairro sdfghjk , localizado em sdfghjk

# %% [markdown]
# Q10

# %%
n1 = float(input("Nota 1: "))
n2 = float(input("Nota 2: "))
n3 = float(input("Nota 3: "))

media = (n1+n2+n3)/3

if media >= 7:
    print("Aprovado")
elif media >= 5:
    print("Recuperação")
else:
    print("Reprovado")

# %% [markdown]
# Q11

# %%
anos = float(input("Anos humanos: "))

if anos < 0:
    print("Erro: valor inválido")
elif anos <= 2:
    resultado = anos * 10.5
else:
    resultado = 21 + (anos - 2) * 4

print("Idade em anos caninos:", resultado)

# %% [markdown]
# Q12

# %%
# Menu
print("===== CALCULADORA =====")
print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")

# Entrada da operação
op = int(input("Escolha uma opção: "))

# Entrada dos números
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

# Lógica das operações
if op == 1:
    resultado = n1 + n2
    print("Resultado:", resultado)

elif op == 2:
    resultado = n1 - n2
    print("Resultado:", resultado)

elif op == 3:
    resultado = n1 * n2
    print("Resultado:", resultado)

elif op == 4:
    if n2 == 0:
        print("Erro: divisão por zero não é permitida.")
    else:
        resultado = n1 / n2
        print("Resultado:", resultado)

else:
    print("Operação inválida.")
